# %%
import heapq
from collections import deque

class Tree_Node:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def arr_to_bin_tree(arr, i=0):
    if i >= len(arr) or arr[i] is None:
        return None

    node = Tree_Node(arr[i])
    node.left = arr_to_bin_tree(arr, 2*i + 1)
    node.right = arr_to_bin_tree(arr, 2*i + 2)
    return node

# %%
def is_complete_tree(root):
    if not root:
        return True
    
    queue = deque([root])
    should_be_leaf = False
    
    while queue:
        node = queue.popleft()
        
        if not node:
            should_be_leaf = True
        else:
            if should_be_leaf:
                return False
            queue.append(node.left)
            queue.append(node.right)
    return True

# %%
min_heap_arr = [1, 2, 3, 4, 5, 6, 7]
complete_tree = arr_to_bin_tree([1, 2, 3, 4, 5, 6])
print(f"Complete tree check: {is_complete_tree(complete_tree)}")
# Out:
# Complete tree check: True
